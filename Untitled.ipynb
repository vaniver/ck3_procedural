# %%
import os

# %%
from continent_gen import *

# %%
source_dir = 'C:\\Program Files (x86)\\Steam\\steamapps\\common\\Crusader Kings III\\game\\history\\'
data_dir = 'C:\\ck3_procedural\\data\\history'
os.makedirs(data_dir, exist_ok=True)
for category in os.listdir(source_dir):
    print(category)
    if category[0] != '_':
        with open(os.path.join(data_dir, category + ".txt"), "w") as outf:
            for filename in os.listdir(os.path.join(source_dir, category)):
                outf.write(filename)
# Out:
# characters
# cultures
# provinces
# province_mapping
# titles
# wars
# _characters.info
# _history.info
# _provinces.info

# %%
import shutil

# %%
culrel_map ={
 'k_aquitaine': ("occitan","catholic"),
 'k_bavaria': ("bavarian","catholic"),
 'k_burgundy': ("french","catholic"),
 'k_egypt': ("egyptian","ashari"),
 'k_france': ("french","catholic"),
 'k_hungary': ("hungarian","catholic"),
 'k_pomerania': ("pommeranian","catholic"),
 'k_syria': ("levantine","ashari"),
 'k_yemen': ("yemeni","ashari"),
 'b_alsace': ("swabian","catholic"),
 'b_bahrain': ("bedouin","ashari"),
 'b_bohemia': ("czech","catholic"),
 'b_capua': ("sicilian","catholic"),
 'b_east_franconia': ("franconian","catholic"),
 'b_genoa': ("cisalpine","catholic"),
 'b_najd': ("bedouin","ashari"),
 'b_shammar': ("bedouin","catholic"),
 'b_toscana': ("italian","catholic"),
 'b_west_franconia': ("franconian","catholic"),
 'c_latium': ("italian","catholic"),
 'c_lombardia': ("cisalpine","catholic"),
 'c_mecca': ("bedouin","ashari"),
 'c_prussia': ("prussian","catholic"),
 'e_eeurope': ("franconian","catholic"),
 'e_islam': ("bedouin","ashari"),
 'e_weurope': ("italian","catholic"),
 'r_catholic': ("italian","catholic"),
 'r_islam': ("bedouin","ashari"),
}

# %%
data_dir = 'C:\\ck3_procedural\\data'
for title in culrel_map.keys():
    hs_path = os.path.join(data_dir, title, "common", "religion", "holy_sites")
    if os.path.exists(hs_path):
        for religion_file in os.listdir(hs_path):
            hs_names = []
            with open(os.path.join(hs_path, religion_file), encoding='utf8') as inf:
                for line in inf.readlines():
                    if line[0] not in ['\t', '}', '#'] and '=' in line:
                        print(line)
                        hs_names.append(line.split('=')[0].strip())
# Out:
# ﻿bordeaux = {
#
# ﻿salzburg = {
#
# ﻿avignon = {
#
# ﻿sinai = {
#
# ﻿reims = {
#
# ﻿pest = {
#
# ﻿stettin = {
#
# ﻿damascus = {
#
# ﻿sanaa = {
#
# ﻿rome = {
#
# ﻿mecca = {
#
# medina = {
#
# ﻿malbork = {

# %%
hs_names[0][0] == '\ufeff'
# Out:
# True

# %%
"Adam Bob \"Billy Joe\" Tom".split("\"")
# Out:
# ['Adam Bob ', 'Billy Joe', ' Tom']

# %%
SRC_DIR = "C:\\Program Files (x86)\\Steam\\steamapps\\common\\Crusader Kings III\\game\\common"
culture_dict = {}
for culgroup in os.listdir(os.path.join(SRC_DIR, "culture", "cultures")):
    if culgroup[-1] != 't':
        continue
    with open(os.path.join(SRC_DIR, "culture", "cultures", culgroup), encoding='utf8') as inf:
        print(culgroup)
        name = None
        culinfo = {}
        names_mode = False
        names_mode = False
        names_name = None
        dynasty_names_mode = False
        for line in inf.readlines():
            line = line.split("#")[0]
            if len(line) < 2:
                continue
            if names_mode:
                if '}' in line:
                    cul_info[names_name] = name_list
                    names_mode = False
                else:
                    if "\"" in line:
                        sline = line.split("\"")
                        for ind, group in enumerate(sline):
                            if ind % 2 == 1:
                                name_list.append(group)
                            else:
                                name_list.extend(group.strip().split())
                    else:
                        name_list.extend(line.strip().split())
            elif dynasty_names_mode:
                if line.startswith("\t\t}"):
                    cul_info["dynasty_names"] = name_list
                    dynasty_names_mode = False
                else:
                    name_list.append(line.strip())
            if line[1] != "\t" and "{" in line and "=" in line:
                maybe_name = line.split('=')[0].strip()
                if maybe_name not in ["graphical_cultures", "mercenary_names"]:
                    if name:
                        culture_dict[name] = cul_info
                        print(name)
                    name = maybe_name
                    cul_info = {}
            if line.startswith("\t\tmale_names"):
                names_mode = True
                names_name = "male_names"
                name_list = []
            elif line.startswith("\t\tfemale_names"):
                names_mode = True
                names_name = "female_names"
                name_list = []
            elif line.startswith("\t\tdynasty_names"):
                dynasty_names_mode = True
                name_list = []
            elif line.startswith("\t\tdynasty_of_location_prefix"):
                cul_info["dynasty_of_location_prefix"] = line.split('=')[1].strip()
        culture_dict[name] = cul_info
        print(name)
# Out:
# 00_akan.txt
# ﻿akan_group
# akan
# kru
# guan
# 00_arabic.txt
# ﻿arabic_group
# bedouin
# levantine
# egyptian
# maghrebi
# andalusian
# yemeni
# 00_baltic.txt
# ﻿baltic_group
# latgalian
# lithuanian
# prussian
# 00_balto_finnic.txt
# ﻿balto_finnic_group
# finnish
# sami
# estonian
# karelian
# vepsian
# 00_berber.txt
# ﻿berber_group
# butr
# baranis
# zaghawa
# 00_brythonic.txt
# ﻿brythonic_group
# pictish
# welsh
# breton
# cornish
# cumbrian
# 00_burman.txt
# ﻿burman_group
# burmese
# mon
# 00_byzantine.txt
# ﻿byzantine_group
# armenian
# greek
# alan
# georgian
# assyrian
# 00_central_african.txt
# ﻿central_african_group
# kanuri
# hausa
# sao
# nupe
# 00_central_germanic.txt
# ﻿central_germanic_group
# saxon
# franconian
# swabian
# bavarian
# frisian
# dutch
# german
# 00_chinese.txt
# ﻿chinese_group
# han
# 00_dravidian.txt
# ﻿dravidian_group
# tamil
# telugu
# kannada
# 00_east_african.txt
# ﻿east_african_group
# ethiopian
# nubian
# welayta
# daju
# 00_east_slavic.txt
# ﻿east_slavic_group
# russian
# ilmenian
# severian
# volhynian
# 00_frankish.txt
# ﻿frankish_group
# frankish
# french
# norman
# occitan
# outremer
# 00_goidelic.txt
# ﻿goidelic_group
# irish
# gaelic
# 00_iberian.txt
# ﻿iberian_group
# basque
# castilian
# catalan
# portuguese
# visigothic
# galician
# asturleonese
# aragonese
# suebi
# 00_indo_aryan.txt
# ﻿indo_aryan_group
# bengali
# oriya
# assamese
# hindustani
# gujarati
# punjabi
# rajput
# sindhi
# marathi
# kashmiri
# sinhala
# nepali
# 00_iranian.txt
# ﻿iranian_group
# persian
# sogdian
# tocharian
# kurdish
# afghan
# baloch
# saka
# daylamite
# khwarezmian
# tajik
# 00_israelite.txt
# ﻿israelite_group
# ashkenazi
# sephardi
# 00_latin.txt
# ﻿latin_group
# italian
# roman
# cisalpine
# sardinian
# sicilian
# lombard
# 00_magyar.txt
# ﻿magyar_group
# mogyer
# hungarian
# 00_mongolic.txt
# ﻿mongolic_group
# mongol
# buryat
# oirat
# naiman
# kerait
# khitan
# tuyuhun
# jurchen
# 00_north_germanic.txt
# ﻿north_germanic_group
# norse
# swedish
# norwegian
# danish
# 00_qiangic.txt
# ﻿qiangic_group
# tangut
# qiang
# 00_sahelian.txt
# ﻿sahelian_group
# soninke
# bozo
# mossi
# sorko
# gaw
# songhai
# 00_senegambian.txt
# ﻿senegambian_group
# pulaar
# serer
# wolof
# 00_somalian.txt
# ﻿somalian_group
# somali
# beja
# afar
# 00_south_slavic.txt
# ﻿south_slavic_group
# croatian
# bosnian
# serbian
# vlach
# bulgarian
# 00_tibetan.txt
# ﻿tibetan_group
# bodpa
# zhangzhung
# sumpa
# tsangpa
# kirati
# lhomon
# 00_turkic.txt
# ﻿turkic_group
# turkish
# pecheneg
# cuman
# khazar
# bolghar
# bashkir
# avar
# karluk
# kimek
# kipchak
# laktan
# kirghiz
# uyghur
# yughur
# uriankhai
# chuvash
# shatuo
# ongud
# 00_ugro_permian.txt
# ﻿ugro_permian_group
# komi
# khanty
# samoyed
# 00_volga_finnic.txt
# ﻿volga_finnic_group
# mordvin
# merya
# meshchera
# mari
# muroma
# 00_west_african.txt
# ﻿west_african_group
# malinke
# bobo
# gur
# marka
# mel
# 00_west_germanic.txt
# ﻿west_germanic_group
# english
# anglo_saxon
# old_saxon
# scottish
# 00_west_slavic.txt
# ﻿west_slavic_group
# pommeranian
# czech
# polish
# polabian
# slovien
# 00_yoruba.txt
# ﻿yoruba_group
# yoruba
# edo
# igbo
# ewe

# %%
[k for k,v in culture_dict.items() if 'male_names' not in v]
# Out:
# ['\ufeffakan_group',
#  '\ufeffarabic_group',
#  'yemeni',
#  '\ufeffbaltic_group',
#  '\ufeffbalto_finnic_group',
#  '\ufeffberber_group',
#  '\ufeffbrythonic_group',
#  '\ufeffburman_group',
#  '\ufeffbyzantine_group',
#  '\ufeffcentral_african_group',
#  '\ufeffcentral_germanic_group',
#  '\ufeffchinese_group',
#  '\ufeffdravidian_group',
#  '\ufeffeast_african_group',
#  '\ufeffeast_slavic_group',
#  '\ufefffrankish_group',
#  '\ufeffgoidelic_group',
#  '\ufeffiberian_group',
#  '\ufeffindo_aryan_group',
#  '\ufeffiranian_group',
#  '\ufeffisraelite_group',
#  '\ufefflatin_group',
#  '\ufeffmagyar_group',
#  '\ufeffmongolic_group',
#  '\ufeffnorth_germanic_group',
#  '\ufeffqiangic_group',
#  '\ufeffsahelian_group',
#  '\ufeffsenegambian_group',
#  '\ufeffsomalian_group',
#  '\ufeffsouth_slavic_group',
#  '\ufefftibetan_group',
#  '\ufeffturkic_group',
#  '\ufeffugro_permian_group',
#  '\ufeffvolga_finnic_group',
#  '\ufeffwest_african_group',
#  '\ufeffwest_germanic_group',
#  '\ufeffwest_slavic_group',
#  '\ufeffyoruba_group']

# %%
cmap.scale
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35008/736501638.py in <module>
# ----> 1 cmap.scale
#
# NameError: name 'cmap' is not defined

# %%
bnum = 0
castle = []
city = []
church = []
for county in BORDER_SIZE_LIST + BORDER_SIZE_LIST:
    castle.append(bnum)
    city.append(bnum + 1)
    church.append(bnum + 2)
    bnum += county
castle = ", ".join([str(s) for s in castle])
city = ", ".join([str(s) for s in city])
church = ", ".join([str(s) for s in church])
print(f"\t'castle_holding': set({castle}),")
print(f"\t'city_holding': set({city}),")
print(f"\t'church_holding': set({church}),")
# Out:
# 	'castle_holding': set(0, 4, 8, 12, 16, 20),
# 	'city_holding': set(1, 5, 9, 13, 17, 21),
# 	'church_holding': set(2, 6, 10, 14, 18, 22),

# %%
sum(CENTER_SIZE_LIST)
# Out:
# 22

# %%
culture_dict['levantine']
# Out:
# {'dynasty_names': ['"dynn_Nasrid"',
#   '"dynn_Muayyadid"',
#   '"dynn_Isavid"',
#   '"dynn_Shukrid"',
#   '"dynn_Yaruqid"',
#   '"dynn_Qaimid"',
#   '"dynn_Alaid"',
#   '"dynn_Zahirid"',
#   '"dynn_Jamalid"',
#   '"dynn_Izzid"',
#   '"dynn_Bahaid"',
#   '"dynn_Shihabid"',
#   '"dynn_Jalalid"',
#   '"dynn_Yaminid"',
#   '"dynn_Lu_Lu"',
#   '"dynn_Sulaymanid"',
#   '"dynn_Mahmudid"',
#   '"dynn_Bahadur"',
#   '"dynn_Ata-Malik"',
#   '"dynn_Ma_anid"',
#   '"dynn_Hamdanid"',
#   '"dynn_Farooqid"',
#   '"dynn_Elbazid"',
#   '"dynn_Abbarid"',
#   '"dynn_Abbasid"',
#   '"dynn_Shamid"',
#   '"dynn_Allawid"',
#   '"dynn_Aqilid"',
#   '"dynn_Qahtanid"',
#   '"dynn_Bahjatid"',
#   '"dynn_Bekkalid"',
#   '"dynn_Baradid"',
#   '"dynn_Bseisoid"',
#   '"dynn_Fattaid"',
#   '"dynn_Fazilid"',
#   '"dynn_Gheisarid"',
#   '"dynn_Hayekid"',
#   '"dynn_Ibrahimid"',
#   '"dynn_Abdel_Nour"',
#   '"dynn_Abdilla"',
#   '"dynn_Mahdi"',
#   '{ "dynnp_el-" "dynn_Khattab" }',
#   '"dynn_Moneim"',
#   '"dynn_Moosevi"',
#   '"dynn_Mubarak"',
#   '"dynn_Moustapha"',
#   '"dynn_Nader"',
#   '"dynn_Nafti"',
#   '"dynn_Alam"',
#   '"dynn_Naeemi"',
#   '"dynn_Nahhas"',
#   '"dynn_Nimri"',
#   '"dynn_Himsi"',
#   '"dynn_Haleem"',
#   '"dynn_Qaderi"',
#   '"dynn_Aqabid"',
#   '"dynn_Jalalid"',
#   '"dynn_Jarraid"',
#   '"dynn_Arishid"',
#   '"dynn_Jasemid"',
#   '"dynn_Abdelid"',
#   '"dynn_Alivid"',
#   '"dynn_Qasimid"',
#   '"dynn_Shaddad"',
#   '{ "dynnp_al-" "dynn_Nafis" }',
#   '{ "dynnp_al-" "dynn_Baghdadi" }',
#   '{ "dynnp_al-" "dynn_Dakhwar" }',
#   '{ "dynnp_al-" "dynn_Suri" }',
#   '"dynn_Khorasani"',
#   '{ "dynnp_al-" "dynn_Hasanid" }',
#   '"dynn_Aqabid"'],
#  'male_names': ['Abdul-Azeem',
#   'Abdul-Hamid',
#   'Abdul-Lateef',
#   'Abdul-Razzaq',
#   'Abdul-Wahad',
#   'Abdullah',
#   'Adhid',
#   'Adil',
#   'Akab',
#   'Ala_i',
#   'Ali',
#   'Amir',
#   'Ashraf',
#   'Aziz',
#   'Bashar',
#   'Boutros',
#   'Da_ud',
#   'Faisal',
#   'Fayiz',
#   'Ghazi',
#   'Hakam',
#   'Hamdan',
#   'Hashmaddin',
#   'Hussayn',
#   'Ibrahim',
#   'Imamaddin',
#   'Isa',
#   'Is_mail',
#   'Ismat',
#   'Jahan',
#   'Jamil',
#   'Kamran',
#   'Khalid',
#   'Khudayar',
#   'Majid',
#   'Mas_ud',
#   'Muaddam',
#   'Muhammad',
#   'Muhsin',
#   'Mukhtar',
#   'Murad',
#   'Musa',
#   'Muzaffar',
#   'Muzaffaraddin',
#   'Nasraddin',
#   'Nuraddin',
#   'Nuri',
#   'Radhi',
#   'Rasul',
#   'Sa_ud',
#   'Salahaddin',
#   'Seyfullah',
#   'Sharaf',
#   'Sirhan',
#   'Taimur',
#   'Tawfiq',
#   'Umaya',
#   'Wahid',
#   'Yahya',
#   'Ya_qub',
#   'Yasar',
#   'Youkhanna',
#   'Zahir'],
#  'female_names': ['Aisha',
#   'Aziza',
#   'Duha',
#   'Farida',
#   'Golbahar',
#   'Gulnar',
#   'Gulnaz',
#   'Gulpari',
#   'Hafsa',
#   'Hasti',
#   'Huma',
#   'Ibtisam',
#   'Jalila',
#   'Kamala',
#   'Karima',
#   'Khandan',
#   'Khaterah',
#   'Khatira',
#   'Kinah',
#   'Lala',
#   'Madiha',
#   'Mahdokht',
#   'Mahsa',
#   'Mahwash',
#   'Marwa',
#   'Mastana',
#   'Mehri',
#   'Mina',
#   'Minoo',
#   'Munawwar',
#   'Muzhdah',
#   'Nahal',
#   'Najela',
#   'Nasiba',
#   'Nastaran',
#   'Nazaneen',
#   'Nazy',
#   'Neelab',
#   'Negar',
#   'Niki',
#   'Nikoo',
#   'Noushin',
#   'Rabiya',
#   'Rajiya',
#   'Sadiya',
#   'Salma',
#   'Sitara',
#   'Thana',
#   'Zahra',
#   'Zuhayra'],
#  'dynasty_of_location_prefix': '"dynnp_mn"'}

# %%
data_dir = 'C:\\ck3_procedural\\data'
for title in os.listdir(data_dir):
    if title[0] not in ["b", "c", "k"]:
        continue
    with open(os.path.join(data_dir, title, "common", "landed_titles", "landed_titles.txt"), encoding='utf8') as inf:
        broke = False
        bnum = 0
        for line in inf.readlines():
            if "province = P" in line:
                try:
                    front, back = line.split("= P")
                    if back:
                        if back.strip() != str(bnum):
                            broke = True
                    else:
                        broke = True
                except:
                    continue
                bnum += 1
        if broke:
            print(title)

# %%
coa_dict = {}
shortcut_dict = {}
with open('C:\\Program Files (x86)\\Steam\\steamapps\\common\\Crusader Kings III\\game\\common\\coat_of_arms\\coat_of_arms\\01_landed_titles.txt','r', encoding='UTF8') as infile:
    coa_buffer = ""
    title_name = ""
    awake = False
    for line in infile:
        if line[0] == '@' or line[1] == '@':
            if line[0] == '\ufeff':
                line = line[1:]
            shortcut_name = line[0:line.find(' ')]
            shortcut_dict[shortcut_name] = line
        if line[0] != '\t' and "=" in line and "{" in line and awake == False:
            title_name = line.split("=")[0].strip()
            coa_buffer = line
            awake = True
        elif awake and line[0] == "}":
            coa_buffer += line
            coa_dict[title_name] = coa_buffer
            title_name = ""
            awake = False
        elif awake:
            coa_buffer += line

data_dir = 'C:\\ck3_procedural\\data'
for title in os.listdir(data_dir):
    if title[0] not in ["b", "c", "k"]:
        continue
    with open(os.path.join(data_dir, title, "common", "landed_titles", "landed_titles.txt"), encoding='utf8') as inf:
        buffer = ""
        for line in inf.readlines():
            if "=" in line and "{" in line and "_" in line:
                small_title = line.split("=")[0].strip()
                if small_title in coa_dict:
                    buffer += coa_dict[small_title]
        if len(buffer) > 0:
            out_dir = os.path.join(data_dir, title, "common", "coat_of_arms", "coat_of_arms")
            os.makedirs(out_dir, exist_ok=True)
            with open(os.path.join(out_dir, f"{title}.txt"), 'w', encoding='utf8') as outf:
                for shortcut, shortcut_text in shortcut_dict.items():
                    if shortcut in buffer:
                        outf.write(shortcut_text)
                outf.write(buffer)

# %%
geo_regions = []
with open("C:\\Program Files (x86)\\Steam\\steamapps\\common\\Crusader Kings III\\game\\map_data\\geographical_region.txt", encoding='utf8') as inf:
    for line in inf:
        if line[0] != "\t" and line[0] != "#" and "=" in line and "{" in line:
            geo_regions.append(line[:line.find(" ")])
with open('C:\\ck3_procedural\\data\\temp_geo.txt', 'w', encoding='utf8') as outf:
    for geo_region in geo_regions:
        outf.write(geo_region)
        outf.write("= {\n\tduchies = {\n\t}\n}\n")

# %%
holy_sites = []
with open("C:\\Program Files (x86)\\Steam\\steamapps\\common\\Crusader Kings III\\game\\common\\religion\\holy_sites\\00_holy_sites.txt", encoding='utf8') as inf:
    for line in inf:
        if line[0] != "\t" and "=" in line and "{" in line:
            holy_sites.append(line[:line.find(" ")])
print(", ".join([f"\"{h}\"" for h in holy_sites]))
# Out:
# "jerusalem", "rome", "cologne", "santiago", "kent", "segrada_familia", "constantinople", "alexandria", "antioch", "aksum", "napata", "suenik", "colonea", "beirut", "baghdad", "farz", "kerala", "armagh", "iona", "visoki", "ragusa", "esztergom", "mecca", "medina", "cordoba", "sinai", "tinmallal", "fes", "nadjaf", "damascus", "siffa", "kufa", "basra", "nizwa", "sijilmasa", "bahrein", "yamama", "sinjar", "baalbek", "lalish", "nishapur", "dashtestan", "zozan", "semien", "sufed", "gerizim", "ahvaz", "samarkand", "udabhanda", "toledo", "memphis", "bodh_gaya", "kusinagara", "sarnath", "sanchi", "ajanta", "sagya", "dagon", "pagan", "atamasthana", "amaravati", "varanasi", "ayodhya", "mathura", "haridwar", "kanchipuram", "ujjayini", "dwarka", "palitana", "shikharj", "ranakpur", "ellora", "sittannavasal", "itanagar", "pemako", "rima", "tezu", "kathmandu", "ilam", "garwhal", "jumla", "maowun", "ngawa", "chakla", "gyaitang", "rebgong", "xingqing", "yijinai", "alxa", "yazd", "nok_kundi", "takht-i-sangin", "takht-e_soleyman", "ushi-darena", "uppsala", "lejre", "paderborn", "zeeland", "ranaheim", "jorvik", "konugardr", "raivola", "hiiumaa", "akkel", "perm", "kiev", "novgorod", "barlad", "plock", "pokaini", "torun", "braslau", "rugen", "pest", "kerch", "olvia", "poszony", "sarysyn", "kara_khorum", "qayaliq", "tavan_bogd", "preslav", "athens", "carthage", "olympus", "sparta", "kabul", "multan", "bost", "khotan", "balkh", "lhasa", "purang", "tyumen", "surgut", "ob", "olkhon", "awkar", "jenne", "niani", "kukiya", "wadan", "daura", "garumele", "igbo", "el_fasher", "wandala", "kisi", "sherbro", "kayor", "kasa", "bono", "kumasi", "ife", "nikki", "aswan", "wadi_el_milk", "naqis", "sennar", "danakil", "kaffa", "harar", "makhir", "mogadishu", "gilgit", "suzhou"

# %%
holy_sites
# Out:
# []

# %%
data_dir = 'C:\\ck3_procedural\\data'
for title in os.listdir(data_dir):
    out_dir = os.path.join(data_dir, title, "common", "coat_of_arms", "coat_of_arms", f"{title}.txt")
    if os.path.exists(out_dir):
        with open(os.path.join("C:\\Users\\Vaniver\\Documents\\Paradox Interactive\\Crusader Kings III\\mod\\testing_worldgen2\\common\\coat_of_arms\\coat_of_arms", f"{title}.txt"), 'w', encoding='utf8') as outf:
            with open(os.path.join(out_dir), encoding='utf8') as inf:
                outf.write(inf.read())

# %%
coa_dict['k_france']
# Out:
# 'k_france = {\n\tpattern = "pattern_solid.dds"\n\tcolor1 = "blue"\n\tcolor2 = "yellow"\n\tcolored_emblem = {\n\t\ttexture = "ce_fleur.dds"\n\t\tcolor1 = "yellow"\n\t\tcolor2 = "yellow"\n\t\tinstance = { position = { 0.10 0.00 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.30 0.00 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.50 0.00 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.70 0.00 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.90 0.00 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.00 0.20 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.20 0.20 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.40 0.20 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.60 0.20 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.80 0.20 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 1.00 0.20 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.10 0.40 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.30 0.40 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.50 0.40 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.70 0.40 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.90 0.40 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.00 0.60 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.20 0.60 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.40 0.60 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.60 0.60 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.80 0.60 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 1.00 0.60 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.10 0.80 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.30 0.80 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.50 0.80 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.70 0.80 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.90 0.80 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.00 1.00 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.20 1.00 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.40 1.00 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.60 1.00 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 0.80 1.00 } scale = { @smLysX @smLysY }  }\n\t\tinstance = { position = { 1.00 1.00 } scale = { @smLysX @smLysY }  }\n\t}\n}\n'

# %%
data_dir = 'C:\\ck3_procedural\\data\\'
for grouping in os.listdir(data_dir):
    if os.path.isfile(os.path.join(data_dir, grouping)):
        continue
    old_loc = os.path.join(data_dir, grouping, "common", "landed_titles.txt")
    if os.path.isfile(old_loc):
        os.makedirs(os.path.join(data_dir, grouping, "common", "landed_titles"), exist_ok=True)
        new_loc = os.path.join(data_dir, grouping, "common", "landed_titles", "landed_titles.txt")
        os.system(f"mv {old_loc} {new_loc}")

# %%
data_dir = 'C:\\ck3_procedural\\data'
for title in ["k_france"]:
    os.makedirs(os.path.join(data_dir, title, "history", "characters"))

# %%
culrel_map = {
 'b_alsace': ("swabian","catholic"),
 'b_bahrain': ("bedouin","ashari"),
 'b_bohemia': ("czech","catholic"),
 'b_capua': ("sicilian","catholic"),
 'b_east_franconia': ("franconian","catholic"),
 'b_genoa': ("cisalpine","catholic"),
 'b_najd': ("bedouin","ashari"),
 'b_shammar': ("bedouin","ashari"),
 'b_toscana': ("italian","catholic"),
 'b_west_franconia': ("franconian","catholic"),
 'c_latium': ("italian","catholic"),
 'c_lombardia': ("cisalpine","catholic"),
 'c_mecca': ("bedouin","ashari"),
 'c_prussia': ("prussian","catholic"),
 'e_eeurope': ("franconian","catholic"),
 'e_islam': ("bedouin","ashari"),
 'e_weurope': ("italian","catholic"),
 'k_aquitaine': ("occitan","catholic"),
 'k_bavaria': ("bavarian","catholic"),
 'k_burgundy': ("french","catholic"),
 'k_egypt': ("egyptian","ashari"),
 'k_france': ("french","catholic"),
 'k_hungary': ("hungarian","catholic"),
 'k_pomerania': ("pommeranian","catholic"),
 'k_syria': ("levantine","ashari"),
 'k_yemen': ("yemeni","ashari"),
 'r_catholic': ("italian","catholic"),
 'r_islam': ("bedouin","ashari"),
}

innovations = {
    "tribal": ["innovation_motte", "innovation_catapult", "innovation_barracks", "innovation_mustering_grounds", "innovation_bannus", "innovation_quilted_armor",
               "innovation_development_01", "innovation_currency_01", "innovation_gavelkind", "innovation_crop_rotation",
               "innovation_city_planning", "innovation_casus_belli", "innovation_plenary_assemblies", "innovation_ledger"],
    "early_medieval": ["innovation_battlements", "innovation_mangonel", "innovation_burhs", "innovation_house_soldiers", "innovation_horseshoes", "innovation_arched_saddle",
                       "innovation_manorialism", "innovation_development_02", "innovation_currency_02", "innovation_royal_prerogative", "innovation_armilary_sphere"],
    "guaranteed": ["innovation_chronicle_writing"]
}

    # innovation_hereditary_rule innovation_baliffs


for title, (culture, religion) in culrel_map:
    with open() as outf:
        outf.write(f"#{culture}\n\n900.1.1 = {{\n")
        outf.write("\n".join(f"\tdiscover_innovation = {i}" for i in innovations["tribal"]))
        outf.write("\n}}\n\n1000.1.1 = {{\n")
        random.shuffle(innovations["early_medieval"])
        outf.write("\n".join(f"\tdiscover_innovation = {i}" for i in innovations["guaranteed"]))
        outf.write("\n")
        outf.write("\n".join(f"\tdiscover_innovation = {i}" for i in innovations["early_medieval"][:3]))
        outf.write("\n}}\n\n1000.1.1 = {{\n")
# Out:
# ' this out'

# %%
import random

# %%
import os
title_name = 'k_pomerania'
out_dir = f'C:\\ck3_procedural\\data\\{title_name}'
os.makedirs(out_dir, exist_ok=True)
with open('C:\\Program Files (x86)\\Steam\\steamapps\\common\\Crusader Kings III\\game\\common\\landed_titles\\00_landed_titles.txt','r', encoding='UTF8') as infile:
    with open(os.path.join(out_dir, 'landed_titles.txt'), 'w', encoding='UTF8') as outfile:
        awake = False
        for line in infile.readlines():
            if line.startswith(f"\t{title_name}"):
                awake = True
            if awake:
                if "province =" in line:
                    outfile.write("\t\t\t\t\tprovince = P\n")
                else:
                    outfile.write(line)
            if line.startswith("\t}"):
                awake = False

# %%
import os
old_name = 'd_genoa'
new_name = 'b_' + old_name[2:]
out_dir = f'C:\\ck3_procedural\\data\\{new_name}'
os.makedirs(out_dir, exist_ok=True)
with open('C:\\Program Files (x86)\\Steam\\steamapps\\common\\Crusader Kings III\\game\\common\\landed_titles\\00_landed_titles.txt','r', encoding='UTF8') as infile:
    with open(os.path.join(out_dir, 'landed_titles.txt'), 'w', encoding='UTF8') as outfile:
        awake = False
        tabs = {'e': '', 'k': '\t', 'd': '\t\t', 'c':'\t\t\t'}[old_name[0]]
        for line in infile.readlines():
            if line.startswith(tabs + old_name):
                awake = True
            if awake:
                if "province =" in line:
                    outfile.write("\t\t\t\t\tprovince = P\n")
                else:
                    outfile.write(line)
            if line.startswith(tabs + "}"):
                awake = False

# %%
with open("C:\\Users\\Vaniver\\Documents\\Paradox Interactive\\Crusader Kings III\\mod\\sit\\history\\provinces\\01_desperation.txt", 'w', encoding='utf-8') as outf:
    for i in range(9, 832):
        outf.write(f"{i} = {{\n\tculture = test_culture\n\treligion = test_faith\n}}\n")

# %%
with open("C:\\Users\\Vaniver\\Documents\\Paradox Interactive\\Crusader Kings III\\mod\\sit\\common\\landed_titles\\00_landed_titles.txt", "a", encoding='utf-8') as outf:
    for i in range(9, 832):
        outf.write(f"\t\t\t\tb_test_{i} = {{\n\t\t\t\t\tprovince = {i}\n\n\t\t\t\t\tcolor = {{ 170 55 90 }}\n\t\t\t\t\tcolor2 = {{ 255 255 255 }}\n\t\t\t\t}}\n\n")
    outf.write("\t\t\t}\n\t\t}\n\t}\n}\n")

# %%
d_count = 0
k_count = 0
d_name = ""
buffer = ""
with open('C:\\Program Files (x86)\\Steam\\steamapps\\common\\Crusader Kings III\\game\\common\\landed_titles\\00_landed_titles.txt','r', encoding='UTF8') as infile:
    for line in infile.readlines():
        if line.startswith('\t\td_'):
            if d_name != "":
                buffer += f"  {d_name}:\t\t{d_count}\n"
            d_name = line.split('=')[0].strip()
            d_count = 0
        if line.startswith('\tk_'):
            if k_name != "" and k_count > 0:
                buffer += f"  {d_name}:\t\t{d_count}\n"
                print(f"{k_name}:\t\t{k_count}\n{buffer}")
            k_name = line.split('=')[0].strip()
            k_count = 0
            d_count = 0
            buffer = ""
            d_name = ""
        if "province =" in line:
            d_count += 1
            k_count += 1
buffer += f"  {d_name}:\t\t{d_count}\n"
print(f"{k_name}:\t\t{k_count}\n{buffer}")
# Out:
# k_england:		143
#   d_bedford:		19
#   d_northumberland:		11
#   d_lancaster:		11
#   d_york:		19
#   d_norfolk:		12
#   d_hereford:		25
#   d_gloucester:		13
#   d_canterbury:		12
#   d_somerset:		14
#   d_cornwall:		7
#
# k_wales:		31
#   d_gwynedd:		12
#   d_powys:		7
#   d_deheubarth:		12
#
# k_scotland:		77
#   d_albany:		17
#   d_the_isles:		2
#   d_galloway:		13
#   d_western_isles:		10
#   d_lothian:		15
#   d_moray:		20
#
# k_ireland:		55
#   d_meath:		8
#   d_ulster:		13
#   d_connacht:		13
#   d_leinster:		8
#   d_munster:		13
#
# k_saxony:		131
#   d_anhalt:		15
#   d_angria:		22
#   d_westfalen:		19
#   d_ostfalen:		15
#   d_holstein:		9
#   d_meissen:		26
#   d_lausitz:		11
#   d_thuringia:		14
#
# k_frisia:		41
#   d_holland:		11
#   d_gelre:		9
#   d_utrecht:		11
#   d_frisia:		10
#
# k_lotharingia:		80
#   d_luxembourg:		15
#   d_brabant:		12
#   d_julich:		12
#   d_upper_lorraine:		20
#   d_lower_lorraine:		21
#
# k_bavaria:		136
#   d_bavaria:		27
#   d_nordgau:		13
#   d_salzburg:		17
#   d_augsburg:		14
#   d_steyermark:		12
#   d_osterreich:		21
#   d_tyrol:		8
#   d_carinthia:		13
#   d_krain:		7
#   d_istria:		4
#
# k_east_francia:		125
#   d_west_franconia:		39
#   d_east_franconia:		25
#   d_hesse:		14
#   d_currezia:		10
#   d_alsace:		13
#   d_swabia:		24
#
# k_bohemia:		53
#   d_bohemia:		35
#   d_moravia:		18
#
# k_thessalonika:		68
#   d_thrace:		12
#   d_strymon:		10
#   d_aegean_islands:		18
#   d_thessalonika:		13
#   d_thessaly:		15
#
# k_epirus:		35
#   d_epirus:		15
#   d_dyrrachion:		16
#   d_cephalonia:		4
#
# k_hellas:		24
#   d_athens:		9
#   d_achaia:		15
#
# k_krete:		6
#   d_krete:		6
#
# k_croatia:		85
#   d_dalmatia:		10
#   d_croatia:		13
#   d_slavonia:		15
#   d_bosna:		18
#   d_lower_bosna:		12
#   d_usora:		15
#   d_ragusa:		2
#
# k_serbia:		41
#   d_rashka:		21
#   d_macva:		8
#   d_duklja:		12
#
# k_bulgaria:		95
#   d_vidin:		8
#   d_turnovo:		26
#   d_dobrudja:		7
#   d_bulgaria:		28
#   d_philippopolis:		26
#
# k_cyprus:		6
#   d_cyprus:		6
#
# k_nikaea:		66
#   d_opsikion:		19
#   d_ephese:		9
#   d_thracesia:		17
#   d_optimatoi:		7
#   d_bucellaria:		14
#
# k_anatolia:		81
#   d_cilicia:		16
#   d_cibyrrhaeot:		15
#   d_anatolia:		30
#   d_cappadocia:		8
#   d_charsianon:		12
#
# k_pontus:		52
#   d_paphlagonia:		8
#   d_armeniac:		14
#   d_sebasteia:		12
#   d_chaldia:		18
#
# k_armenia:		48
#   d_mesopotamia:		11
#   d_vaspurakan:		13
#   d_greater_armenia:		24
#
# k_georgia:		44
#   d_tao-klarjeti:		12
#   d_abkhazia:		16
#   d_georgia:		16
#
# k_sicily:		53
#   d_sicily:		14
#   d_benevento:		8
#   d_capua:		6
#   d_apulia:		10
#   d_salerno:		6
#   d_calabria:		9
#
# k_venice:		4
#   d_venice:		4
#
# k_italy:		90
#   d_friuli:		9
#   d_verona:		12
#   d_piedmonte:		12
#   d_lombardia:		25
#   d_genoa:		5
#   d_emilia:		7
#   d_pisa:		3
#   d_toscana:		17
#
# k_sardinia:		19
#   d_corsica:		6
#   d_sardinia:		13
#
# k_romagna:		48
#   d_romagna:		13
#   d_ancona:		10
#   d_spoleto:		12
#   d_latium:		13
#
# k_sweden:		88
#   d_svealand:		14
#   d_bergslagen:		16
#   d_vastergotland:		13
#   d_ostergotland:		10
#   d_smaland:		19
#   d_norrland:		12
#   d_gotland:		4
#
# k_sapmi:		72
#   d_aarjetje:		12
#   d_vuovdisamieana:		12
#   d_duortnoseatnu:		13
#   d_giemajohka:		22
#   d_guoldat:		13
#
# k_denmark:		44
#   d_sjaelland:		10
#   d_skane:		13
#   d_jylland:		12
#   d_slesvig:		9
#
# k_norway:		92
#   d_viken:		15
#   d_agder:		6
#   d_vestlandi:		13
#   d_trandalog:		9
#   d_dalir:		11
#   d_halogaland:		11
#   d_iceland:		9
#   d_northern_isles:		3
#   d_jamtland:		15
#
# k_finland:		59
#   d_finland:		16
#   d_savo:		10
#   d_pohjanmaa:		11
#   d_karelia:		22
#
# k_esthonia:		21
#   d_esthonia:		11
#   d_livonia:		10
#
# k_poland:		121
#   d_lesser_poland:		29
#   d_wielkopolska:		22
#   d_mazovia:		20
#   d_upper_silesia:		15
#   d_lower_silesia:		19
#   d_kuyavia:		16
#
# k_pomerania:		62
#   d_pommerania:		19
#   d_nordmark:		13
#   d_pomerelia:		14
#   d_ostmark:		16
#
# k_lithuania:		83
#   d_lithuanians:		15
#   d_prussia:		16
#   d_masuria:		12
#   d_courland:		14
#   d_latgalians:		12
#   d_samogitia:		14
#
# k_galicia-volhynia:		40
#   d_volhynia:		15
#   d_halych:		15
#   d_cherven_cities:		10
#
# k_ruthenia:		79
#   d_kiev:		22
#   d_turov:		11
#   d_pereyaslavl:		14
#   d_chernigov:		19
#   d_karachev:		9
#   d_novosil:		4
#
# k_novgorod:		40
#   d_novgorod:		21
#   d_vepsia:		10
#   d_luki:		9
#
# k_white_rus:		51
#   d_grodno:		7
#   d_pinsk:		12
#   d_minsk:		7
#   d_polotsk:		8
#   d_smolensk:		17
#
# k_opolye:		46
#   d_opolye:		23
#   d_ryazan:		12
#   d_nizhny_novgorod:		11
#
# k_bjarmaland:		54
#   d_biarmia:		16
#   d_chudia:		10
#   d_vologda:		14
#   d_ustyug:		14
#
# k_pontic_steppe:		61
#   d_yedisan:		21
#   d_levedia:		16
#   d_don_valley:		16
#   d_crimea:		8
#
# k_caucasus:		43
#   d_khazaria:		9
#   d_azov:		11
#   d_alania:		11
#   d_ciscaucasia:		12
#
# k_caspian_steppe:		24
#   d_itil:		12
#   d_pecheneg:		12
#
# k_volga_bulgaria:		53
#   d_volga_bulgaria:		17
#   d_kazan:		14
#   d_jalmat:		16
#   d_martyuba:		6
#
# k_mordvinia:		55
#   d_mordvinia:		15
#   d_voronezh:		10
#   d_chuvashia:		13
#   d_khopyor:		17
#
# k_permia:		40
#   d_perm:		16
#   d_ural:		10
#   d_udmurtia:		14
#
# k_bashkiria:		34
#   d_bashkiria:		12
#   d_uraltau:		12
#   d_vogulia:		10
#
# k_yugra:		34
#   d_ostyaki:		12
#   d_konda:		8
#   d_pelym:		6
#   d_kazym:		8
#
# k_sibir:		42
#   d_sibir:		12
#   d_ishim:		8
#   d_tara:		10
#   d_lanikaz:		12
#
# k_ob:		99
#   d_salair:		32
#   d_ala_tau:		24
#   d_vasyugan_mire:		13
#   d_baraba_steppe:		15
#   d_kulyndy_steppe:		15
#
# k_mongolia:		107
#   d_otuken:		17
#   d_ogrash:		11
#   d_selenga_valley:		16
#   d_ovorkhangai:		16
#   d_arkhangai:		10
#   d_khovsgol:		8
#   d_gobi_altai:		8
#   d_ubsunur_hollow:		15
#   d_khovd:		6
#
# k_tuva:		28
#   d_togina:		9
#   d_tannu_ola:		7
#   d_western_sayan:		12
#
# k_khakassia:		48
#   d_khakass_hollow:		19
#   d_shoria:		9
#   d_kargassia:		9
#   d_eastern_sayan:		11
#
# k_buryatia:		47
#   d_uda_valley:		7
#   d_dauria:		12
#   d_bargujin_tukum:		12
#   d_baigaluuls:		7
#   d_tsagaanbaigal:		9
#
# k_angara:		46
#   d_yenisei_kan:		15
#   d_chuna_valley:		11
#   d_lena:		8
#   d_angara:		12
#
# k_zhetysu:		56
#   d_zhetysu:		20
#   d_alakol:		14
#   d_tarbagatai:		12
#   d_ili-alatau:		10
#
# k_kimek:		42
#   d_mugodzhar_hills:		11
#   d_aqtobe:		12
#   d_atyrau:		19
#
# k_cuman:		72
#   d_turgay:		16
#   d_kurgan:		7
#   d_kush-murun:		13
#   d_saryarka:		19
#   d_kazakh:		17
#
# k_kipchak:		67
#   d_semey:		22
#   d_kentarlau:		12
#   d_karkaraly:		12
#   d_karabas:		10
#   d_betpa:		11
#
# k_dzungaria:		64
#   d_kara_khoja:		24
#   d_altay:		20
#   d_gurbantunggut:		10
#   d_naiman_gobi:		10
#
# k_khotan:		67
#   d_khotan:		17
#   d_kashgar:		17
#   d_karashar:		18
#   d_charkliq:		15
#
# k_oghuz_il:		57
#   d_transcaspiana:		16
#   d_jemba:		14
#   d_aral_il:		15
#   d_barsuki:		12
#
# k_syr_darya:		46
#   d_syr_darya:		11
#   d_chah:		15
#   d_muyunkum:		20
#
# k_transoxiana:		132
#   d_soghd:		28
#   d_badakhshan:		17
#   d_khuttal:		16
#   d_osrushana:		9
#   d_ferghana:		26
#   d_khorezm:		25
#   d_uzboy:		11
#
# k_persia:		143
#   d_isfahan:		15
#   d_kirman:		21
#   d_yazd:		14
#   d_rayy:		10
#   d_hamadan:		12
#   d_fars:		31
#   d_hormuz:		8
#   d_khuzestan:		22
#   d_kermanshah:		10
#
# k_khorasan:		105
#   d_nishapur:		21
#   d_merv:		28
#   d_ghur:		10
#   d_herat:		16
#   d_balkh:		14
#   d_nasa:		6
#   d_kohestan:		10
#
# k_daylam:		69
#   d_daylam:		9
#   d_tabaristan:		9
#   d_gurgan:		8
#   d_azerbaijan:		26
#   d_shirvan:		17
#
# k_makran:		61
#   d_makran:		24
#   d_jabal_kufs:		14
#   d_sistan:		23
#
# k_kabulistan:		28
#   d_kabul:		11
#   d_zabulistan:		17
#
# k_mesopotamia:		62
#   d_samarra:		15
#   d_wasit:		5
#   d_kufa:		15
#   d_basra:		11
#   d_baghdad:		16
#
# k_jazira:		71
#   d_diyarrabia:		27
#   d_diyarmudar:		8
#   d_diyarbakr:		20
#   d_euphrates:		6
#   d_kurdistan:		10
#
# k_dacia:		39
#   d_transylvanian_alps:		10
#   d_muntenia:		16
#   d_oltenia:		13
#
# k_moldavia:		37
#   d_bukovina:		13
#   d_moldova:		15
#   d_bugeac:		9
#
# k_hungary:		170
#   d_visegrad:		16
#   d_somogy:		14
#   d_nyitra:		28
#   d_ungvar:		17
#   d_transcarpathia:		10
#   d_transylvania:		29
#   d_bihar:		22
#   d_temes:		14
#   d_bacs:		6
#   d_gyor:		11
#   d_syrmia:		3
#
# k_france:		158
#   d_valois:		26
#   d_berry:		12
#   d_anjou:		13
#   d_normandy:		21
#   d_orleans:		16
#   d_champagne:		24
#   d_burgundy:		20
#   d_bar:		10
#   d_flanders:		16
#
# k_aquitaine:		116
#   d_gascogne:		16
#   d_aquitaine:		17
#   d_toulouse:		18
#   d_languedoc:		16
#   d_armagnac:		13
#   d_poitou:		14
#   d_auvergne:		11
#   d_bourbon:		11
#
# k_brittany:		17
#   d_brittany:		17
#
# k_burgundy:		65
#   d_provence:		19
#   d_savoie:		13
#   d_dauphine:		15
#   d_upper_burgundy:		11
#   d_transjurania:		7
#
# k_andalusia:		62
#   d_cordoba:		12
#   d_granada:		11
#   d_sevilla:		16
#   d_toledo:		23
#
# k_badajoz:		32
#   d_beja:		12
#   d_badajoz:		15
#   d_algarve:		5
#
# k_valencia:		31
#   d_valencia:		14
#   d_mallorca:		4
#   d_murcia:		13
#
# k_castille:		23
#   d_castilla:		16
#   d_cantabria:		7
#
# k_aragon:		39
#   d_aragon:		19
#   d_barcelona:		20
#
# k_navarra:		12
#   d_navarra:		8
#   d_viscaya:		4
#
# k_leon:		25
#   d_leon:		17
#   d_asturias:		8
#
# k_spanish_galicia:		18
#   d_galicia:		18
#
# k_portugal:		19
#   d_porto:		8
#   d_coimbra:		11
#
# k_maghreb:		82
#   d_marrakesh:		24
#   d_sous:		16
#   d_tafilalt:		8
#   d_fes:		20
#   d_rif:		9
#   d_canarias:		5
#
# k_tahert:		64
#   d_tlemcen:		14
#   d_tahert:		15
#   d_alger:		7
#   d_bejaia:		6
#   d_zab:		10
#   d_mzab:		12
#
# k_africa:		71
#   d_kairouan:		13
#   d_tunis:		14
#   d_kroumerie:		8
#   d_gabes:		5
#   d_jerid:		11
#   d_tripolitania:		11
#   d_syrte:		9
#
# k_anbiya:		29
#   d_zammour:		8
#   d_adrar:		8
#   d_touat:		7
#   d_taghaza:		6
#
# k_sahara:		49
#   d_tadmekka:		5
#   d_ghat:		10
#   d_air:		6
#   d_kawar:		10
#   d_tibesti:		9
#   d_fezzan:		9
#
# k_arabia:		144
#   d_jawf:		9
#   d_amman:		8
#   d_shammar:		15
#   d_medina:		20
#   d_mecca:		14
#   d_asir:		5
#   d_najd:		26
#   d_yamama:		8
#   d_al-hasa:		9
#   d_bahrain:		10
#   d_oman:		20
#
# k_yemen:		53
#   d_sanaa:		15
#   d_jawf-al-yamani:		6
#   d_taizz:		13
#   d_hadramawt:		9
#   d_mahra:		8
#   d_socotra:		2
#
# k_egypt:		88
#   d_cyrenaica:		11
#   d_alexandria:		9
#   d_delta:		14
#   d_cairo:		10
#   d_al-wahat:		9
#   d_al-said:		19
#   d_eastern_desert:		6
#   d_sinai:		10
#
# k_jerusalem:		21
#   d_oultrejourdain:		7
#   d_palestine:		8
#   d_urdunn:		6
#
# k_syria:		62
#   d_aleppo:		12
#   d_edessa:		11
#   d_homs:		8
#   d_antioch:		7
#   d_lebanon:		4
#   d_damascus:		13
#   d_palmyra:		7
#
# k_abyssinia:		68
#   d_aksum:		13
#   d_dahlaks:		7
#   d_lasta:		14
#   d_gondar:		11
#   d_gojjam:		10
#   d_showa:		13
#
# k_nubia:		78
#   d_nobatia:		12
#   d_makuria:		27
#   d_shamir:		8
#   d_alwa:		18
#   d_sennar:		13
#
# k_blemmyia:		37
#   d_naqis:		12
#   d_bazin:		7
#   d_baqlin:		18
#
# k_damot:		34
#   d_damot:		14
#   d_kaffa:		9
#   d_sharka:		11
#
# k_adal:		54
#   d_dawaro:		10
#   d_adal:		12
#   d_mora:		6
#   d_danakil:		8
#   d_zaila:		9
#   d_sanaag:		9
#
# k_ajuraan:		40
#   d_hafun:		10
#   d_mogadishu:		16
#   d_west_ajuraan:		14
#
# k_outer_ajuraan:		30
#   d_shabelle:		11
#   d_bali:		8
#   d_samalo:		11
#
# k_kanem:		36
#   d_kanem:		9
#   d_bornu:		16
#   d_kagha:		11
#
# k_sao:		42
#   d_baguirmi:		20
#   d_salamat:		5
#   d_wandala:		17
#
# k_hausaland:		29
#   d_kano:		7
#   d_katsina:		6
#   d_kebbi:		10
#   d_gobir:		6
#
# k_darfur:		53
#   d_darfur:		17
#   d_west_darfur:		9
#   d_wadai:		18
#   d_kordofan:		9
#
# k_songhay:		25
#   d_kawkaw:		10
#   d_timbuktu:		6
#   d_dendi:		9
#
# k_gurma:		37
#   d_lower_gurma:		13
#   d_upper_gurma:		11
#   d_yatenga:		13
#
# k_ghana:		48
#   d_wagadu:		11
#   d_mema:		11
#   d_tagant:		7
#   d_diafunu:		8
#   d_kaniaga:		11
#
# k_mali:		64
#   d_manding:		23
#   d_bambuk:		17
#   d_futa_jalon:		12
#   d_loma:		12
#
# k_takrur:		29
#   d_takrur:		7
#   d_silla:		9
#   d_djolof:		13
#
# k_jenne:		21
#   d_jenne:		16
#   d_bobo:		5
#
# k_kaabu:		27
#   d_kaabu:		8
#   d_wuli:		8
#   d_kasa:		11
#
# k_guinea:		66
#   d_sapi:		12
#   d_kono:		10
#   d_bassa:		9
#   d_toro:		17
#   d_wenyon:		7
#   d_kru:		11
#
# k_kong:		43
#   d_worodugu:		14
#   d_kong:		16
#   d_lobi:		13
#
# k_akan:		57
#   d_ashanti:		17
#   d_adiukru:		9
#   d_gyaman:		7
#   d_brong:		14
#   d_eweland:		10
#
# k_gur:		27
#   d_dagomba:		9
#   d_wagadugu:		6
#   d_mamprusi:		12
#
# k_borgu:		28
#   d_borgu:		16
#   d_savalu:		12
#
# k_yorubaland:		42
#   d_ibadan:		10
#   d_oyo:		17
#   d_ife:		9
#   d_benin:		6
#
# k_igbo-benue:		42
#   d_igboland:		17
#   d_nupe:		15
#   d_kwararafa:		10
#
# k_sindh:		36
#   d_sauvira:		18
#   d_bhakkar:		18
#
# k_punjab:		63
#   d_multan:		20
#   d_lahore:		28
#   d_gandhara:		15
#
# k_delhi:		42
#   d_kuru:		13
#   d_haritanaka:		8
#   d_mathura:		10
#   d_vodamayutja:		11
#
# k_gujarat:		49
#   d_gurjara_mandala:		12
#   d_anartta:		10
#   d_saurashtra:		16
#   d_lata:		11
#
# k_rajputana:		58
#   d_maru:		13
#   d_jangladesh:		8
#   d_stravani:		7
#   d_medapata:		12
#   d_ajmer:		18
#
# k_malwa:		44
#   d_dadhipadra:		14
#   d_akara_dasarna:		17
#   d_anupa:		13
#
# k_kosala:		37
#   d_kanyakubja:		15
#   d_saryupara:		9
#   d_jejakabhukti:		13
#
# k_himalaya:		45
#   d_kurmanchal:		12
#   d_khasa:		15
#   d_nepal:		9
#   d_limbuwan:		9
#
# k_kashmir:		17
#   d_kasmira:		9
#   d_pamir:		8
#
# k_bengal:		60
#   d_gauda:		14
#   d_varendra:		10
#   d_vanga:		19
#   d_nadia:		9
#   d_suhma:		8
#
# k_kamarupa:		27
#   d_kamarupanagara:		7
#   d_sutiya:		8
#   d_para_lauhitya:		12
#
# k_bihar:		46
#   d_magadha:		14
#   d_tirabhukti:		13
#   d_kasi:		7
#   d_jharkand:		12
#
# k_gondwana:		17
#   d_dahala:		9
#   d_ratanpur:		8
#
# k_orissa:		56
#   d_tosali:		22
#   d_daksina_kosala:		16
#   d_kalinga:		11
#   d_dandakaranya:		7
#
# k_pagan:		75
#   d_pagan:		23
#   d_tagaung:		13
#   d_sriksetra:		11
#   d_arakan:		12
#   d_ramannadesa:		16
#
# k_maharastra:		65
#   d_devagiri:		14
#   d_vidharba:		14
#   d_konkana:		11
#   d_nasikya:		8
#   d_rattapadi:		18
#
# k_karnata:		49
#   d_kalyani:		8
#   d_gangavadi:		13
#   d_nulambavadi:		14
#   d_raichur_doab:		14
#
# k_tamilakam:		58
#   d_pandya_nadu:		14
#   d_chola_nadu:		13
#   d_chera_nadu:		14
#   d_tondai_nadu:		17
#
# k_andhra:		18
#   d_udayagiri:		11
#   d_vengi:		7
#
# k_telingana:		17
#   d_warangal:		11
#   d_racakonda:		6
#
# k_lanka:		23
#   d_dakhina_desa:		5
#   d_ruhunu:		6
#   d_sinhala:		12
#
# k_u:		55
#   d_yarlung:		14
#   d_lhasa:		18
#   d_nagchu:		10
#   d_conyi:		13
#
# k_tsang:		42
#   d_xigaze:		9
#   d_sagya:		15
#   d_ngamring:		10
#   d_nyima:		8
#
# k_kham:		71
#   d_qamdo:		17
#   d_boyul:		8
#   d_nyingchi:		7
#   d_nangqen:		4
#   d_lhatok:		7
#   d_lingtsang:		4
#   d_dege:		8
#   d_batang:		10
#   d_litang:		6
#
# k_amdo:		64
#   d_xining:		5
#   d_tuyuhun:		16
#   d_nagormo:		13
#   d_amdo:		15
#   d_zadoi:		9
#   d_qumarleb:		6
#
# k_gyalrong:		53
#   d_gyalrong:		17
#   d_chakla:		12
#   d_golog:		8
#   d_malho:		7
#   d_gainlho:		9
#
# k_guge:		41
#   d_ngari:		16
#   d_kinnaur:		7
#   d_purang:		18
#
# k_maryul:		40
#   d_ladakh:		11
#   d_zanskar:		7
#   d_baltiyul:		8
#   d_aksai_chin:		7
#   d_rutog:		7
#
# k_lhomon:		48
#   d_bumthang:		8
#   d_paro:		11
#   d_monyul:		7
#   d_lhoyul:		11
#   d_dzayul:		11
#
# k_xia:		87
#   d_xia:		7
#   d_wuluhai:		6
#   d_zhenfan:		8
#   d_liangzhou:		13
#   d_shanzhou:		6
#   d_qilin:		4
#   d_ganzhou:		16
#   d_yijinai:		8
#   d_guiyi:		15
#   d_aksay:		4

# %%
out_dir = os.path.join('C:\\ck3_procedural\\data\\', new_name)
count = 0
d_name = ''
with open(os.path.join(out_dir, 'landed_titles.txt'), 'r', encoding='UTF8') as infile:
    for line in infile.readlines():
        if line.startswith('\t\td_'):
            print(d_name, count)
            d_name = line.split('=')[0].strip()
            count = 0
        if "province =" in line:
            count += 1
print(d_name, count)
# Out:
#  0
# d_sicily 14
# d_benevento 8
# d_capua 6
# d_apulia 10
# d_salerno 6
# d_calabria 9

# %%
for title_name in os.listdir('C:\\ck3_procedural\\data\\'):
    out_file = os.path.join('C:\\ck3_procedural\\data\\', title_name, "common", "landed_titles", "landed_titles.txt")
    if title_name[0] == 'k':
        present = [False] * 61
    elif title_name[0] == 'b':
        present = [False] * 24
    elif title_name[0] == 'c':
        present = [False] * 22
    else:
        continue
    with open(out_file, 'r', encoding='UTF8') as infile:
        left_brace = 0
        right_brace = 0
        extra = 0
        for line in infile.readlines():
            if '{' in line:
                left_brace += 1
            if '}' in line:
                right_brace += 1
            if "province =" in line:
                pid = line.split('=')[1].strip()[1:]
                if len(pid) == 0:
                    extra += 1
                else:
                    present[int(pid)] = True
    if all(present) and extra == 0 and left_brace == right_brace:
        print(title_name, "Correct!")
    else:
        print(title_name, "Error!")
        if not(all(present)):
            missing = []
            for pind, p in enumerate(present):
                if not p:
                    missing.append(pind)
            print("\tmissing: ", missing)
        if extra != 0:
            print("\textra: ", extra)
        if left_brace != right_brace:
            print("\tleft: ", left_brace, "right: ", right_brace)
# Out:
# b_alsace Correct!
# b_bahrain Correct!
# b_bohemia Correct!
# b_capua Correct!
# b_east_franconia Correct!
# b_genoa Correct!
# b_najd Correct!
# b_shammar Correct!
# b_toscana Correct!
# b_west_franconia Correct!
# c_latium Correct!
# c_lombardia Correct!
# c_mecca Correct!
# c_prussia Correct!
# k_aquitaine Correct!
# k_bavaria Correct!
# k_burgundy Correct!
# k_egypt Correct!
# k_france Correct!
# k_hungary Correct!
# k_pomerania Correct!
# k_syria Correct!
# k_yemen Correct!

# %%
baronies = set()
used_baronies = set()
with open(os.path.join(out_dir, 'landed_titles.txt'), 'r', encoding='UTF8') as file1:
    for line in file1.readlines():
        if line.startswith('\t\t\t\tb_'):
            baronies.add(line.strip().split()[0])
with open(os.path.join(out_dir, 'landed_titles2.txt'), 'r', encoding='UTF8') as file2:
    for line in file2.readlines():
        if line.startswith('\t\t\t\tb_'):
            used_baronies.add(line.strip().split()[0])
print(baronies - used_baronies)
# Out:
# {'b_havelberg', 'b_gustrow', 'b_stralsund', 'b_klenow'}

# %%
p_id = 0
print('\tk_ ' + str(sum([sum(d) for d in KINGDOM_SIZE_LIST])))
for d in KINGDOM_SIZE_LIST:
    print('\t\td_ ' + str(sum(d)))
    for c in d:
        print('\t\t\tc_' + str(c))
        for b in range(c):
            print('\t\t\t\tP' + str(p_id))
            p_id += 1
# Out:
# 	k_ 61
# 		d_ 22
# 			c_6
# 				P0
# 				P1
# 				P2
# 				P3
# 				P4
# 				P5
# 			c_4
# 				P6
# 				P7
# 				P8
# 				P9
# 			c_4
# 				P10
# 				P11
# 				P12
# 				P13
# 			c_4
# 				P14
# 				P15
# 				P16
# 				P17
# 			c_4
# 				P18
# 				P19
# 				P20
# 				P21
# 		d_ 14
# 			c_4
# 				P22
# 				P23
# 				P24
# 				P25
# 			c_4
# 				P26
# 				P27
# 				P28
# 				P29
# 			c_3
# 				P30
# 				P31
# 				P32
# 			c_3
# 				P33
# 				P34
# 				P35
# 		d_ 14
# 			c_4
# 				P36
# 				P37
# 				P38
# 				P39
# 			c_4
# 				P40
# 				P41
# 				P42
# 				P43
# 			c_3
# 				P44
# 				P45
# 				P46
# 			c_3
# 				P47
# 				P48
# 				P49
# 		d_ 11
# 			c_4
# 				P50
# 				P51
# 				P52
# 				P53
# 			c_4
# 				P54
# 				P55
# 				P56
# 				P57
# 			c_3
# 				P58
# 				P59
# 				P60

# %%
p_id = 0
print('\tb_ ' + str(2 * sum(BORDER_SIZE_LIST)))
for d in [BORDER_SIZE_LIST, BORDER_SIZE_LIST]:
    print('\t\td_ ' + str(sum(d)))
    for c in d:
        print('\t\t\tc_' + str(c))
        for b in range(c):
            print('\t\t\t\tP' + str(p_id))
            p_id += 1
# Out:
# 	b_ 24
# 		d_ 12
# 			c_4
# 				P0
# 				P1
# 				P2
# 				P3
# 			c_4
# 				P4
# 				P5
# 				P6
# 				P7
# 			c_4
# 				P8
# 				P9
# 				P10
# 				P11
# 		d_ 12
# 			c_4
# 				P12
# 				P13
# 				P14
# 				P15
# 			c_4
# 				P16
# 				P17
# 				P18
# 				P19
# 			c_4
# 				P20
# 				P21
# 				P22
# 				P23

# %%
filedir = 'C:\\Program Files (x86)\\Steam\\steamapps\\common\\Victoria 2\\mod\\'
mod_names = ['WOBG_roll_' + str(x) for x in range(4,7)]
filedir_prov = 'history\\provinces\\'
filedir_pop = 'history\\pops\\1836.1.1'
filedir_names = 'history\\countries'

# %%
import numpy as np

# %%
data = {}
for mod_name in mod_names:
    data[mod_name] = {'owner': {}, 'trade_good': {}, 'pops': {} }
    for region in os.listdir(os.path.join(filedir, mod_name, filedir_prov)):
        for province in os.listdir(os.path.join(filedir, mod_name, filedir_prov, region)):
            pid = int(province.split(' ')[0])
            with open(os.path.join(filedir, mod_name, filedir_prov, region, province)) as file:
                for line in file.readlines():
                    if 'owner' in line:
                        data[mod_name]['owner'][pid] = line.split('=')[-1].strip()
                    if 'trade_goods' in line:
                        data[mod_name]['trade_good'][pid] = line.split('=')[-1].strip()
    
    for region in os.listdir(os.path.join(filedir, mod_name, filedir_pop)):
        with open(os.path.join(filedir, mod_name, filedir_pop, region)) as file:
            pid = -1
            record = False
            for line in file.readlines():
                if '\t' not in line and '=' in  line and '{' in line:
                    pid = int(line.split()[0])
                    data[mod_name]['pops'][pid] = 0
                if 'farmers' in line:
                    record = True
                if 'size' in line and record:
                    record = False
                    data[mod_name]['pops'][pid] += int(line.split()[-1])

# %%
data[mod_names[0]]['pops'][100]
# Out:
# 22149

# %%
data[mod_names[0]]['owner'][100]
# Out:
# 'MEX'

# %%
data[mod_names[0]]['trade_good'][100]
# Out:
# 'fruit'

# %%
namefix =

# %%
tag_data = {}
for mod_name in mod_names:
    tags = sorted(set(data[mod_name]['owner'].values()))
    trade_goods = sorted(set(data[mod_name]['trade_good'].values()))
    tag_data[mod_name] = {tag: {'display_name': '',
                                'pids': [],
                                'trade_goods_count': {tg: 0 for tg in trade_goods},
                                'trade_goods_pop': {tg: 0 for tg in trade_goods},
                                'oil_count': 0,
                                'oil_pop': 0,
                                'rubber_count': 0,
                                'rubber_pop': 0,
                               } for tag in tags}
    for tag, display_name in {x.split()[0]: x.split()[-1].split('.')[0] for x in os.listdir(os.path.join(filedir, mod_name, filedir_names))}.items():
        if tag in tag_data[mod_name]:
            tag_data[mod_name][tag]['display_name'] = display_name
    for pid, tag in data[mod_name]['owner'].items():
        tag_data[mod_name][tag]['pids'].append(pid)
    for tag in tags:
        for pid in tag_data[mod_name][tag]['pids']:
            trade_good = data[mod_name]['trade_good'][pid]
            tag_data[mod_name][tag]['trade_goods_count'][trade_good] += 1
            tag_data[mod_name][tag]['trade_goods_pop'][trade_good] += data[mod_name]['pops'][pid]

# %%
for mod_name in mod_names:
    unclaimed_rubber = 0
    unclaimed_oil = 0
    with open(os.path.join(filedir, mod_name, 'events\\goods.txt')) as file:
        rubber = False
        oil = False
        for line in file.readlines():
            if line == '\tid = 1100\n':
                gold = True
            if line == '\tid = 1107\n':
                rubber = True
            if line == '\tid = 1109\n':
                rubber = False
                oil = True
            if 'province_id' in line:
                pid = int(line.split('=')[-1].strip())
                if pid in data[mod_name]['owner']:
                    if rubber:
                        tag_data[mod_name][data[mod_name]['owner'][pid]]['rubber_count'] += 1
                        tag_data[mod_name][data[mod_name]['owner'][pid]]['rubber_pop'] += data[mod_name]['pops'][pid]
                    elif oil:
                        tag_data[mod_name][data[mod_name]['owner'][pid]]['oil_count'] += 1
                        tag_data[mod_name][data[mod_name]['owner'][pid]]['oil_pop'] += data[mod_name]['pops'][pid]
                else:
                    if rubber:
                        unclaimed_rubber += 1
                    elif oil:
                        unclaimed_oil +=1
    print(mod_name)
    print('rubber:', unclaimed_rubber)
    print('oil:', unclaimed_oil)
# Out:
# WOBG_roll_4
# rubber: 9
# oil: 1
# WOBG_roll_5
# rubber: 4
# oil: 5
# WOBG_roll_6
# rubber: 9
# oil: 5

# %%
mod_name
# Out:
# 'WOBG_roll_4'

# %%
[pid for pid in tag_data[mod_name]['ENL']['pids'] if data[mod_name]['trade_good'][pid] == 'sulphur']
# Out:
# [515, 275, 279, 284, 288, 300]

# %%
','.join([str(x[0])+','+str(x[1]) for x in zip(tag_data['WOBG_roll_1']['FLA']['trade_goods_count'].values(), tag_data['WOBG_roll_1']['FLA']['trade_goods_pop'].values())])
# Out:
# '8,188916,13,325065,4,93585,10,253584,0,0,15,380031,13,306297,37,926592,6,187905,0,0,0,0,1,29203,2,46523,3,59893,14,327229,4,60563,3,105023,13,314326'

# %%
alt_tags = [(len(tag_data[mod_names[0]][tag]['pids']), tag) for tag in tags]
alt_tags = [x[1] for x in sorted(alt_tags, reverse=True)]

# %%
for mod_name in mod_names:
    with open(f'{mod_name}.csv','w') as file:
        file.write('tag,display_name,' + ','.join([x + '_count,' + x + '_pop' for x in trade_goods])+',oil_count,oil_pop,rubber_count,rubber_pop\n')
        for tag in alt_tags:
            buffer = ','.join([str(x[0])+','+str(x[1]) for x in zip(tag_data[mod_name][tag]['trade_goods_count'].values(),
                                                                    tag_data[mod_name][tag]['trade_goods_pop'].values())])
            buffer2 = ','.join([str(tag_data[mod_name][tag][y]) for y in ['oil_count', 'oil_pop', 'rubber_count', 'rubber_pop']])
            file.write(','.join([tag, tag_data[mod_name][tag]['display_name'], buffer, buffer2]) +'\n')

# %%
player_tags = ['EGY']
for mod_name in mod_names:
    with open(f'{mod_name}.csv','w') as file:
        file.write('tag,display_name,' + ','.join([x + '_count,' + x + '_pop' for x in trade_goods]))
        for tag in tags:
            buffer = ','.join([str(x[0])+','+str(x[1]) for x in zip(tag_data[mod_name][tag]['trade_goods_count'].values(),
                                                                    tag_data[mod_name][tag]['trade_goods_pop'].values())])
            file.write(','.join([tag, tag_data[mod_name][tag]['display_name'], buffer]) +'\n')

# %%
display_names = {x.split()[0]: x.split()[-1].split('.')[0] for x in display_names}

# %%
cul_data = {}
for mod_name in mod_names:
    cul_data[mod_name] = {'owner': {}, 'trade_good': {}, 'pops': {} }
    for region in os.listdir(os.path.join(filedir, mod_name, filedir_prov)):
        for province in os.listdir(os.path.join(filedir, mod_name, filedir_prov, region)):
            pid = int(province.split(' ')[0])
            with open(os.path.join(filedir, mod_name, filedir_prov, region, province)) as file:
                for line in file.readlines():
                    if 'owner' in line:
                        data[mod_name]['owner'][pid] = line.split('=')[-1].strip()
                    if 'trade_goods' in line:
                        data[mod_name]['trade_good'][pid] = line.split('=')[-1].strip()
    
    for region in os.listdir(os.path.join(filedir, mod_name, filedir_pop)):
        with open(os.path.join(filedir, mod_name, filedir_pop, region)) as file:
            pid = -1
            record = False
            for line in file.readlines():
                if '\t' not in line and '=' in  line and '{' in line:
                    pid = int(line.split()[0])
                    data[mod_name]['pops'][pid] = 0
                if 'farmers' in line:
                    record = True
                if 'size' in line and record:
                    record = False
                    data[mod_name]['pops'][pid] += int(line.split()[-1])
# Out:
# {'display_name': '',
#  'pids': [2048,
#   2115,
#   2116,
#   2117,
#   2118,
#   2119,
#   2120,
#   2121,
#   2122,
#   1331,
#   1619,
#   1620,
#   1621,
#   1622,
#   1623,
#   1624,
#   1625,
#   1626,
#   1627,
#   1628,
#   1629,
#   1630,
#   1631,
#   1632,
#   1633,
#   1634,
#   1635,
#   1636,
#   1637,
#   1477,
#   1482,
#   1483,
#   1484,
#   1485,
#   1486,
#   1487,
#   1537,
#   1538,
#   1539,
#   1540,
#   1541,
#   1543,
#   1544,
#   1604,
#   1605,
#   1606,
#   1607,
#   1608,
#   1609,
#   1610,
#   1611,
#   2221,
#   2562,
#   1321,
#   1322,
#   1323,
#   1324,
#   1455,
#   1456,
#   1457,
#   1458,
#   1459,
#   1460,
#   1461,
#   1462,
#   1463,
#   1464,
#   2528,
#   2529,
#   2530,
#   2531,
#   2565,
#   1638,
#   1639,
#   1640,
#   1641,
#   1642,
#   1643,
#   1644,
#   1645,
#   1646,
#   1647,
#   1648,
#   1649,
#   1650,
#   1651,
#   1652,
#   1653,
#   1654,
#   1655,
#   1656,
#   1657,
#   1658,
#   1659,
#   1660,
#   1661,
#   1662,
#   1663,
#   1664,
#   1665,
#   1666,
#   1667,
#   1668,
#   1669,
#   1670,
#   1671,
#   1672,
#   1673,
#   1674,
#   1675,
#   1676,
#   1677,
#   1678,
#   1679,
#   1531,
#   2517,
#   2518,
#   2519,
#   2521,
#   2522,
#   2523,
#   2526,
#   2534,
#   2535,
#   2536,
#   2537,
#   2539,
#   2543,
#   2544,
#   2546,
#   2547,
#   2579,
#   610,
#   686,
#   2131,
#   1086,
#   1087,
#   1088,
#   1089,
#   658],
#  'trade_goods_count': {'cattle': 18,
#   'coal': 7,
#   'coffee': 2,
#   'cotton': 9,
#   'dye': 1,
#   'fish': 15,
#   'fruit': 7,
#   'grain': 34,
#   'iron': 8,
#   'opium': 0,
#   'precious_metal': 0,
#   'silk': 4,
#   'sulphur': 0,
#   'tea': 9,
#   'timber': 12,
#   'tobacco': 5,
#   'tropical_wood': 5,
#   'wool': 4},
#  'trade_goods_pop': {'cattle': 497570,
#   'coal': 108573,
#   'coffee': 18379,
#   'cotton': 234932,
#   'dye': 11078,
#   'fish': 366612,
#   'fruit': 173158,
#   'grain': 752136,
#   'iron': 182817,
#   'opium': 0,
#   'precious_metal': 0,
#   'silk': 168702,
#   'sulphur': 0,
#   'tea': 210553,
#   'timber': 297880,
#   'tobacco': 128702,
#   'tropical_wood': 58504,
#   'wool': 151704}}

# %%
[x + '_count,' + x + '_pop,' for x in trade_goods]
# Out:
# ['cattle',
#  'coal',
#  'coffee',
#  'cotton',
#  'dye',
#  'fish',
#  'fruit',
#  'grain',
#  'iron',
#  'opium',
#  'precious_metal',
#  'silk',
#  'sulphur',
#  'tea',
#  'timber',
#  'tobacco',
#  'tropical_wood',
#  'wool']
